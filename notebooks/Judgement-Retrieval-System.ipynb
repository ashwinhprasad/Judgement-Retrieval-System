# %%
# importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import string
import nltk
from nltk.corpus import stopwords

# %%
# downloading stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# importing the dataset
df = pd.read_csv('/content/drive/MyDrive/Smart-India-Hackathon/datasets/clean_data.csv')
df.head(2)
# Out:
#    Unnamed: 0     ID                 name  \
# 0           0  50606          Roe v. Wade
# 1           1  50613  Stanley v. Illinois
#
#                                       href   docket  term  \
# 0    https://api.oyez.org/cases/1971/70-18    70-18  1971
# 1  https://api.oyez.org/cases/1971/70-5014  70-5014  1971
#
#            first_party second_party  \
# 0             Jane Roe   Henry Wade
# 1  Peter Stanley, Sr.      Illinois
#
#                                                facts  facts_len  \
# 0  <p>In 1970, Jane Roe (a fictional name used in...        501
# 1  <p>Joan Stanley had three children with Peter ...        757
#
#    majority_vote  minority_vote first_party_winner     decision_type  \
# 0              7              2               True  majority opinion
# 1              5              2               True  majority opinion
#
#          disposition    issue_area
# 0           reversed           NaN
# 1  reversed/remanded  Civil Rights

# %%
# some minimal preprocessing for the case abstracts
df.drop(['Unnamed: 0','facts_len'],inplace=True,axis=1)
df.set_index('ID',inplace=True)
df['facts'] = df['facts'].str.replace('<p>','')
df['facts'] = df['facts'].str.replace('</p>','')
df['facts'] = df['facts'].str.replace('\n','')
judgements_pre = df['facts']
df.head(2)
# Out:
#                       name                                     href   docket  \
# ID
# 50606          Roe v. Wade    https://api.oyez.org/cases/1971/70-18    70-18
# 50613  Stanley v. Illinois  https://api.oyez.org/cases/1971/70-5014  70-5014
#
#        term          first_party second_party  \
# ID
# 50606  1971             Jane Roe   Henry Wade
# 50613  1971  Peter Stanley, Sr.      Illinois
#
#                                                    facts  majority_vote  \
# ID
# 50606  In 1970, Jane Roe (a fictional name used in co...              7
# 50613  Joan Stanley had three children with Peter Sta...              5
#
#        minority_vote first_party_winner     decision_type        disposition  \
# ID
# 50606              2               True  majority opinion           reversed
# 50613              2               True  majority opinion  reversed/remanded
#
#          issue_area
# ID
# 50606           NaN
# 50613  Civil Rights

# %%
# custom pre-processsors
def remove_punctuations(text):
    text = [letter for letter in text if letter not in string.punctuation]
    text = ''.join(text)
    text = text.strip()
    return text

def remove_stop_words(text):
    text = [word for word in text.split(' ') if word not in stopwords.words('english')]
    text = ' '.join(text)
    text = text.strip()
    return text

# %%
# remove punctuations and stopwords
df['facts'] = df['facts'].apply(remove_punctuations)
df['facts'] = df['facts'].apply(remove_stop_words)

# %%
# create the facts vector
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
facts_matrix = vectorizer.fit_transform(df['facts'])

# %%
# user input
from sklearn.metrics.pairwise import linear_kernel
random_sample = vectorizer.transform([df['facts'].iloc[0]])
cosine_similarity = linear_kernel(random_sample,facts_matrix)
df['similarity'] = cosine_similarity.reshape(-1)
df.sort_values(by='similarity',ascending=False).head(2)
# Out:
#                name                                     href   docket  term  \
# ID
# 50606   Roe v. Wade    https://api.oyez.org/cases/1971/70-18    70-18  1971
# 51602  Maher v. Roe  https://api.oyez.org/cases/1976/75-1440  75-1440  1976
#
#       first_party second_party  \
# ID
# 50606    Jane Roe   Henry Wade
# 51602       Maher          Roe
#
#                                                    facts  majority_vote  \
# ID
# 50606  In 1970 Jane Roe fictional name used court doc...              7
# 51602  In wake Roe v Wade Connecticut Welfare Departm...              6
#
#        minority_vote first_party_winner     decision_type        disposition  \
# ID
# 50606              2               True  majority opinion           reversed
# 51602              3               True  majority opinion  reversed/remanded
#
#       issue_area  similarity
# ID
# 50606        NaN    1.000000
# 51602    Privacy    0.234849

# %%
# saving the dependencies
pickle.dump(vectorizer,open('vectorizer.pkl','wb'))
pickle.dump(facts_matrix,open('facts_matrix.pkl','wb'))
